# %% [markdown]
# # Requirements

# %%
# !git clone https://github.com/Dene33/keras_Realtime_Multi-Person_Pose_Estimation.git
# !pip install configobj
# !sudo apt install ffmpeg
# !sudo apt-get install blender

# !sudo apt install python2.7 python-pip
# !git clone https://github.com/Dene33/hmr.git
# !wget https://people.eecs.berkeley.edu/~kanazawa/cachedir/hmr/models.tar.gz && tar -xf models.tar.gz
# !mv models hmr/
# !pip2 install -r hmr/requirements.txt
# !mkdir hmr/output
# !mkdir hmr/output/csv
# !mkdir hmr/output/images
# !mkdir hmr/output/csv_joined
# !mkdir hmr/output/bvh_animation

# !python2 -m pip install keras==2.2.0
# Out:
# DEPRECATION: Python 2.7 reached the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 is no longer maintained. pip 21.0 will drop support for Python 2.7 in January 2021. More details about Python 2 support in pip can be found at https://pip.pypa.io/en/latest/development/release-process/#python-2-support pip 21.0 will remove support for this functionality.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting keras==2.2.0
#   Downloading Keras-2.2.0-py2.py3-none-any.whl (300 kB)
#      |████████████████████████████████| 300 kB 5.4 MB/s eta 0:00:01
# Collecting keras-preprocessing==1.0.1
#   Downloading Keras_Preprocessing-1.0.1-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: h5py in /home/pc/.local/lib/python2.7/site-packages (from keras==2.2.0) (2.10.0)
# Requirement already satisfied: six>=1.9.0 in /home/pc/.local/lib/python2.7/site-packages (from keras==2.2.0) (1.16.0)
# Requirement already satisfied: scipy>=0.14 in /home/pc/.local/lib/python2.7/site-packages (from keras==2.2.0) (1.2.2)
# Collecting pyyaml
#   Downloading PyYAML-5.4.1-cp27-cp27mu-manylinux1_x86_64.whl (574 kB)
#      |████████████████████████████████| 574 kB 39.8 MB/s eta 0:00:01
# Collecting keras-applications==1.0.2
#   Downloading Keras_Applications-1.0.2-py2.py3-none-any.whl (43 kB)
#      |████████████████████████████████| 43 kB 1.5 MB/s  eta 0:00:01
# Requirement already satisfied: numpy>=1.9.1 in /home/pc/.local/lib/python2.7/site-packages (from keras==2.2.0) (1.16.6)
# Installing collected packages: keras-preprocessing, pyyaml, keras-applications, keras
#   Attempting uninstall: keras-preprocessing
#     Found existing installation: Keras-Preprocessing 1.1.2
#     Uninstalling Keras-Preprocessing-1.1.2:
#       Successfully uninstalled Keras-Preprocessing-1.1.2
#   Attempting uninstall: keras-applications
#     Found existing installation: Keras-Applications 1.0.8
#     Uninstalling Keras-Applications-1.0.8:
#       Successfully uninstalled Keras-Applications-1.0.8
#   Attempting uninstall: keras
#     Found existing installation: keras 2.7.0
#     Uninstalling keras-2.7.0:
#       Successfully uninstalled keras-2.7.0
# Successfully installed keras-2.2.0 keras-applications-1.0.2 keras-preprocessing-1.0.1 pyyaml-5.4.1

# %%
import os
os.chdir('keras_Realtime_Multi-Person_Pose_Estimation')
# !bash model/get_keras_model.sh
# !mkdir sample_jsons
# !mkdir sample_videos
# !mkdir sample_images

# %%
# %cd keras_Realtime_Multi-Person_Pose_Estimation/
# Out:
# /home/pc/Desktop/DeepMimicBvh/keras_Realtime_Multi-Person_Pose_Estimation

# %% [markdown]
# Extract video frames.

# %%
#convert to images, specify fps rate
# !bash video_to_images.sh 24
# Out:
# Processing taekwondokick1
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'sample_videos/taekwondokick1.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     title           : TaekwondoCombo Kicks, Turning Kicks, Single Kicks
#     artist          : vidsources
#     date            : 20110721
#     encoder         : Lavf58.45.100
#     comment         : ** please check out the " 2013 new series " at
#                     : http://www.youtube.com/playlist?list=PL7OH5WTAQSAMdm5pKZVBvwoQnQJk1GHla
#                     :
#                     : We produced our TKD videos together with Master C T Law, Master K M Chan and Master P C Chan of the Hong Kong Practical Taekwondo Association.
#                     :
#                     : 1) Pal chagui
#                     : 2) An pal chagui
#                     : 3) Skip step An pal Chagui
#                     : 4) An Narae chagui
#                     : 5) Narae chagui
#                     : 6) Step back pal chagui
#                     : 7) Dollyio chagui
#                     : 8) Ap chagui correction to Dollyo chagui
#                     : 7) Yeop chagui
#                     : 8) Nerryo Chagui
#                     : 9) Dwit furyo chagui
#                     : 10) Dolque chagui
#                     : 11) Dwit Chagui
#                     : 12) 360'Dwit c.
#                     : 13) An pal c.Nerryo c.14
#                     : 14) Timio bandae Dollyo c.
#                     : 15)  An Furryo chagui
#                     : 16) 360'Bandae Dollyo C.
#                     : 17) 540'Bandae dollyo c.
#                     : 18) Nara chagui19)Seibon narae c.
#                     : 20) Pal c.Dwit Uriki
#                     : 21) Pal c.narae c.Dolque c.
#                     : 22) Pal c.Dolque c. Bandae dollyo c
#                     : 23) Pal chagui Neibon narae chagui dolque c.
#                     : 24) pal c.nerryio c.dwit c.
#                     : 25) Pal c.narae c.
#                     : 26) pal c.narae c. step back pal c.narae c.(neibon)
#                     :
#                     : http://www.hobbypress.net/taekwondo.htm
#                     : http://youtu.be/IihA6Pb0KPw
#                     :
#                     : This video is edited with Corel VideoStudio Pro X4. Sponsored by www.i-software.com.hk
#     description     : ** please check out the " 2013 new series " at
#                     : http://www.youtube.com/playlist?list=PL7OH5WTAQSAMdm5pKZVBvwoQnQJk1GHla
#                     :
#                     : We produced our TKD videos together with Master C T Law, Master K M Chan and Master P C Chan of the Hong Kong Practical Taekwondo Association.
#                     :
#                     : 1) Pal chagui
#                     : 2) An pal chagui
#                     : 3) Skip step An pal Chagui
#                     : 4) An Narae chagui
#                     : 5) Narae chagui
#                     : 6) Step back pal chagui
#                     : 7) Dollyio chagui
#                     : 8) Ap chagui correction to Dollyo chagui
#                     : 7) Yeop chagui
#                     : 8) Nerryo Chagui
#                     : 9) Dwit furyo chagui
#                     : 10) Dolque chagui
#                     : 11) Dwit Chagui
#                     : 12) 360'Dwit c.
#                     : 13) An pal c.Nerryo c.14
#                     : 14) Timio bandae Dollyo c.
#                     : 15)  An Furryo chagui
#                     : 16) 360'Bandae Dollyo C.
#                     : 17) 540'Bandae dollyo c.
#                     : 18) Nara chagui19)Seibon narae c.
#                     : 20) Pal c.Dwit Uriki
#                     : 21) Pal c.narae c.Dolque c.
#                     : 22) Pal c.Dolque c. Bandae dollyo c
#                     : 23) Pal chagui Neibon narae chagui dolque c.
#                     : 24) pal c.nerryio c.dwit c.
#                     : 25) Pal c.narae c.
#                     : 26) pal c.narae c. step back pal c.narae c.(neibon)
#                     :
#                     : http://www.hobbypress.net/taekwondo.htm
#                     : http://youtu.be/IihA6Pb0KPw
#                     :
#                     : This video is edited with Corel VideoStudio Pro X4. Sponsored by www.i-software.com.hk
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 2861 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1218x1080 [SAR 1:1 DAR 203:180], 2714 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to 'sample_images/taekwondokick1%03d.png':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     title           : TaekwondoCombo Kicks, Turning Kicks, Single Kicks
#     artist          : vidsources
#     date            : 20110721
#     description     : ** please check out the " 2013 new series " at
#                     : http://www.youtube.com/playlist?list=PL7OH5WTAQSAMdm5pKZVBvwoQnQJk1GHla
#                     :
#                     : We produced our TKD videos together with Master C T Law, Master K M Chan and Master P C Chan of the Hong Kong Practical Taekwondo Association.
#                     :
#                     : 1) Pal chagui
#                     : 2) An pal chagui
#                     : 3) Skip step An pal Chagui
#                     : 4) An Narae chagui
#                     : 5) Narae chagui
#                     : 6) Step back pal chagui
#                     : 7) Dollyio chagui
#                     : 8) Ap chagui correction to Dollyo chagui
#                     : 7) Yeop chagui
#                     : 8) Nerryo Chagui
#                     : 9) Dwit furyo chagui
#                     : 10) Dolque chagui
#                     : 11) Dwit Chagui
#                     : 12) 360'Dwit c.
#                     : 13) An pal c.Nerryo c.14
#                     : 14) Timio bandae Dollyo c.
#                     : 15)  An Furryo chagui
#                     : 16) 360'Bandae Dollyo C.
#                     : 17) 540'Bandae dollyo c.
#                     : 18) Nara chagui19)Seibon narae c.
#                     : 20) Pal c.Dwit Uriki
#                     : 21) Pal c.narae c.Dolque c.
#                     : 22) Pal c.Dolque c. Bandae dollyo c
#                     : 23) Pal chagui Neibon narae chagui dolque c.
#                     : 24) pal c.nerryio c.dwit c.
#                     : 25) Pal c.narae c.
#                     : 26) pal c.narae c. step back pal c.narae c.(neibon)
#                     :
#                     : http://www.hobbypress.net/taekwondo.htm
#                     : http://youtu.be/IihA6Pb0KPw
#                     :
#                     : This video is edited with Corel VideoStudio Pro X4. Sponsored by www.i-software.com.hk
#     comment         : ** please check out the " 2013 new series " at
#                     : http://www.youtube.com/playlist?list=PL7OH5WTAQSAMdm5pKZVBvwoQnQJk1GHla
#                     :
#                     : We produced our TKD videos together with Master C T Law, Master K M Chan and Master P C Chan of the Hong Kong Practical Taekwondo Association.
#                     :
#                     : 1) Pal chagui
#                     : 2) An pal chagui
#                     : 3) Skip step An pal Chagui
#                     : 4) An Narae chagui
#                     : 5) Narae chagui
#                     : 6) Step back pal chagui
#                     : 7) Dollyio chagui
#                     : 8) Ap chagui correction to Dollyo chagui
#                     : 7) Yeop chagui
#                     : 8) Nerryo Chagui
#                     : 9) Dwit furyo chagui
#                     : 10) Dolque chagui
#                     : 11) Dwit Chagui
#                     : 12) 360'Dwit c.
#                     : 13) An pal c.Nerryo c.14
#                     : 14) Timio bandae Dollyo c.
#                     : 15)  An Furryo chagui
#                     : 16) 360'Bandae Dollyo C.
#                     : 17) 540'Bandae dollyo c.
#                     : 18) Nara chagui19)Seibon narae c.
#                     : 20) Pal c.Dwit Uriki
#                     : 21) Pal c.narae c.Dolque c.
#                     : 22) Pal c.Dolque c. Bandae dollyo c
#                     : 23) Pal chagui Neibon narae chagui dolque c.
#                     : 24) pal c.nerryio c.dwit c.
#                     : 25) Pal c.narae c.
#                     : 26) pal c.narae c. step back pal c.narae c.(neibon)
#                     :
#                     : http://www.hobbypress.net/taekwondo.htm
#                     : http://youtu.be/IihA6Pb0KPw
#                     :
#                     : This video is edited with Corel VideoStudio Pro X4. Sponsored by www.i-software.com.hk
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: png, rgb24, 1218x1080 [SAR 1:1 DAR 203:180], q=2-31, 200 kb/s, 24 fps, 24 tbn, 24 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 png
# frame=   62 fps=3.8 q=-0.0 Lsize=N/A time=00:00:02.58 bitrate=N/A dup=0 drop=13 speed=0.156x
# video:53177kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# Done

# %% [markdown]
# Load model.

# %%
exec(open('model_load.py').read())
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Run 2D pose estimation.

# %%
# 2d pose estimation. For each image creates corresponding .json file with format
# similar to output .json format of openpose (https://github.com/CMU-Perceptual-Computing-Lab/openpose)
exec(open('2d_pose_estimation.py').read())
# Out:
# ('Now proccessing:', 'taekwondokick1007.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1028.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1023.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1052.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1029.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1026.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1030.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1041.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1050.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1056.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1005.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1024.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1036.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1055.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1051.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1025.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1032.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1054.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1045.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1040.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1004.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1013.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1031.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1002.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1010.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1037.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1042.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1039.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1015.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1035.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1034.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1011.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1060.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1046.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1019.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1059.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1027.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1003.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1020.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1009.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1017.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1006.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1038.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1061.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1016.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1057.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1012.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1033.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1062.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1014.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1008.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1021.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1018.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1058.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1053.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1047.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1001.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1043.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1022.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1044.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1049.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)
# ('Now proccessing:', 'taekwondokick1048.png')
# Input shape: (1, 184, 208, 3)
# Output shape (heatmap): (1, 23, 26, 19)
# Input shape: (1, 368, 416, 3)
# Output shape (heatmap): (1, 46, 52, 19)
# Input shape: (1, 552, 624, 3)
# Output shape (heatmap): (1, 69, 78, 19)
# Input shape: (1, 736, 832, 3)
# Output shape (heatmap): (1, 92, 104, 19)

# %% [markdown]
# Run 3D pose estimation.

# %%
# !python2 -m pip install configobj
# Out:
# DEPRECATION: Python 2.7 reached the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 is no longer maintained. pip 21.0 will drop support for Python 2.7 in January 2021. More details about Python 2 support in pip can be found at https://pip.pypa.io/en/latest/development/release-process/#python-2-support pip 21.0 will remove support for this functionality.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting configobj
#   Downloading configobj-5.0.6.tar.gz (33 kB)
# Requirement already satisfied: six in /home/pc/.local/lib/python2.7/site-packages (from configobj) (1.16.0)
# Building wheels for collected packages: configobj
#   Building wheel for configobj (setup.py) ... done
#   Created wheel for configobj: filename=configobj-5.0.6-py2-none-any.whl size=34544 sha256=f28bac7c569efb19bddfed41875df3c37368e0ce83f73aeb4d2f28aad3068a6c
#   Stored in directory: /home/pc/.cache/pip/wheels/c1/12/7a/c676d85d30d1aa17f3882dab925a777ab1f651c4072cccefd7
# Successfully built configobj
# Installing collected packages: configobj
# Successfully installed configobj-5.0.6

# %%
#3d pose estimation
# os.chdir('..')
# !bash hmr/3dpose_estimate.sh
# Out:
# Processing taekwondokick1001
# 2022-01-15 07:19:11.457227: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:19:11.458469: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:19:11.458507: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:19:11.458526: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:19:11.458543: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# Iteration 0
# Iteration 1
# Reuse is on!
# Iteration 2
# Reuse is on!
# Restoring checkpoint /home/pc/Desktop/DeepMimicBvh/hmr/src/../models/model.ckpt-667589..
# /home/pc/Desktop/DeepMimicBvh/hmr/src/util/renderer.py:313: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(image.dtype, np.float):
#
# Result is in hmr/output (you can open images in Colaboratory by double-clicking them)
# Processing taekwondokick1002
# 2022-01-15 07:19:46.409850: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:19:46.409894: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:19:46.409904: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:19:46.409913: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:19:46.409950: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# Iteration 0
# Iteration 1
# Reuse is on!
# Iteration 2
# Reuse is on!
# Restoring checkpoint /home/pc/Desktop/DeepMimicBvh/hmr/src/../models/model.ckpt-667589..
# /home/pc/Desktop/DeepMimicBvh/hmr/src/util/renderer.py:313: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(image.dtype, np.float):
#
# Result is in hmr/output (you can open images in Colaboratory by double-clicking them)
# Processing taekwondokick1003
# 2022-01-15 07:20:04.818339: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:20:04.818489: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:20:04.818521: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:20:04.818543: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:20:04.818563: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# Iteration 0
# Iteration 1
# Reuse is on!
# Iteration 2
# Reuse is on!
# Restoring checkpoint /home/pc/Desktop/DeepMimicBvh/hmr/src/../models/model.ckpt-667589..
# /home/pc/Desktop/DeepMimicBvh/hmr/src/util/renderer.py:313: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(image.dtype, np.float):
#
# Result is in hmr/output (you can open images in Colaboratory by double-clicking them)
# Processing taekwondokick1004
# 2022-01-15 07:20:22.987244: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:20:22.987281: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:20:22.987291: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:20:22.987300: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:20:22.987324: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# Iteration 0
# Iteration 1
# Reuse is on!
# Iteration 2
# Reuse is on!
# Restoring checkpoint /home/pc/Desktop/DeepMimicBvh/hmr/src/../models/model.ckpt-667589..
# /home/pc/Desktop/DeepMimicBvh/hmr/src/util/renderer.py:313: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(image.dtype, np.float):
#
# Result is in hmr/output (you can open images in Colaboratory by double-clicking them)
# Processing taekwondokick1005
# 2022-01-15 07:20:40.102856: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:20:40.102898: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:20:40.102909: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:20:40.102917: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:20:40.102942: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# Iteration 0
# Iteration 1
# Reuse is on!
# Iteration 2
# Reuse is on!
# Restoring checkpoint /home/pc/Desktop/DeepMimicBvh/hmr/src/../models/model.ckpt-667589..
# /home/pc/Desktop/DeepMimicBvh/hmr/src/util/renderer.py:313: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(image.dtype, np.float):
#
# Result is in hmr/output (you can open images in Colaboratory by double-clicking them)
# Processing taekwondokick1006
# 2022-01-15 07:20:57.198040: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:20:57.198160: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:20:57.198186: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:20:57.198206: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:20:57.198225: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# Iteration 0
# Iteration 1
# Reuse is on!
# Iteration 2
# Reuse is on!
# Restoring checkpoint /home/pc/Desktop/DeepMimicBvh/hmr/src/../models/model.ckpt-667589..
# /home/pc/Desktop/DeepMimicBvh/hmr/src/util/renderer.py:313: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(image.dtype, np.float):
#
# Result is in hmr/output (you can open images in Colaboratory by double-clicking them)
# Processing taekwondokick1007
# 2022-01-15 07:21:16.518317: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:21:16.518368: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:21:16.518471: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:21:16.518493: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:21:16.518511: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# Iteration 0
# Iteration 1
# Reuse is on!
# Iteration 2
# Reuse is on!
# Restoring checkpoint /home/pc/Desktop/DeepMimicBvh/hmr/src/../models/model.ckpt-667589..
# /home/pc/Desktop/DeepMimicBvh/hmr/src/util/renderer.py:313: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(image.dtype, np.float):
#
# Result is in hmr/output (you can open images in Colaboratory by double-clicking them)
# Processing taekwondokick1008
# 2022-01-15 07:21:33.590142: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:21:33.590204: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:21:33.590221: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:21:33.590236: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:21:33.590252: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# Iteration 0
# Iteration 1
# Reuse is on!
# Iteration 2
# Reuse is on!
# Restoring checkpoint /home/pc/Desktop/DeepMimicBvh/hmr/src/../models/model.ckpt-667589..
# /home/pc/Desktop/DeepMimicBvh/hmr/src/util/renderer.py:313: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(image.dtype, np.float):
#
# Result is in hmr/output (you can open images in Colaboratory by double-clicking them)
# Processing taekwondokick1009
# 2022-01-15 07:21:50.340701: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:21:50.340758: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:21:50.340775: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:21:50.340790: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:21:50.340806: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# Iteration 0
# Iteration 1
# Reuse is on!
# Iteration 2
# Reuse is on!
# Restoring checkpoint /home/pc/Desktop/DeepMimicBvh/hmr/src/../models/model.ckpt-667589..
# /home/pc/Desktop/DeepMimicBvh/hmr/src/util/renderer.py:313: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(image.dtype, np.float):
#
# Result is in hmr/output (you can open images in Colaboratory by double-clicking them)
# Processing taekwondokick1010
# 2022-01-15 07:22:07.303905: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:22:07.304045: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:22:07.304068: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:22:07.304086: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:22:07.304125: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# Iteration 0
# Iteration 1
# Reuse is on!
# Iteration 2
# Reuse is on!
# Restoring checkpoint /home/pc/Desktop/DeepMimicBvh/hmr/src/../models/model.ckpt-667589..
# /home/pc/Desktop/DeepMimicBvh/hmr/src/util/renderer.py:313: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(image.dtype, np.float):
#
# Result is in hmr/output (you can open images in Colaboratory by double-clicking them)
# Processing taekwondokick1011
# 2022-01-15 07:22:24.189511: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:22:24.189693: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:22:24.189731: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:22:24.189758: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:22:24.189784: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# Iteration 0
# Iteration 1
# Reuse is on!
# Iteration 2
# Reuse is on!
# Restoring checkpoint /home/pc/Desktop/DeepMimicBvh/hmr/src/../models/model.ckpt-667589..
# /home/pc/Desktop/DeepMimicBvh/hmr/src/util/renderer.py:313: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(image.dtype, np.float):
#
# Result is in hmr/output (you can open images in Colaboratory by double-clicking them)
# Processing taekwondokick1012
# 2022-01-15 07:22:41.102385: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:22:41.102424: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:22:41.102434: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:22:41.102442: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:22:41.102457: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# Iteration 0
# Iteration 1
# Reuse is on!
# Iteration 2
# Reuse is on!
# Restoring checkpoint /home/pc/Desktop/DeepMimicBvh/hmr/src/../models/model.ckpt-667589..
# /home/pc/Desktop/DeepMimicBvh/hmr/src/util/renderer.py:313: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(image.dtype, np.float):
#
# Result is in hmr/output (you can open images in Colaboratory by double-clicking them)
# Processing taekwondokick1013
# 2022-01-15 07:22:57.727854: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:22:57.727895: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:22:57.727905: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:22:57.727914: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:22:57.727925: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# Iteration 0
# Iteration 1
# Reuse is on!
# Iteration 2
# Reuse is on!
# Restoring checkpoint /home/pc/Desktop/DeepMimicBvh/hmr/src/../models/model.ckpt-667589..
# /home/pc/Desktop/DeepMimicBvh/hmr/src/util/renderer.py:313: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(image.dtype, np.float):
#
# Result is in hmr/output (you can open images in Colaboratory by double-clicking them)
# Processing taekwondokick1014
# 2022-01-15 07:23:14.675333: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:23:14.675379: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:23:14.675390: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:23:14.675398: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:23:14.675407: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# Iteration 0
# Iteration 1
# Reuse is on!
# Iteration 2
# Reuse is on!
# Restoring checkpoint /home/pc/Desktop/DeepMimicBvh/hmr/src/../models/model.ckpt-667589..
# /home/pc/Desktop/DeepMimicBvh/hmr/src/util/renderer.py:313: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(image.dtype, np.float):
#
# Result is in hmr/output (you can open images in Colaboratory by double-clicking them)
# Processing taekwondokick1015
# 2022-01-15 07:23:32.291638: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:23:32.291779: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:23:32.291804: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:23:32.291821: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:23:32.291840: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# Iteration 0
# Iteration 1
# Reuse is on!
# Iteration 2
# Reuse is on!
# Restoring checkpoint /home/pc/Desktop/DeepMimicBvh/hmr/src/../models/model.ckpt-667589..
# /home/pc/Desktop/DeepMimicBvh/hmr/src/util/renderer.py:313: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(image.dtype, np.float):
#
# Result is in hmr/output (you can open images in Colaboratory by double-clicking them)
# Processing taekwondokick1016
# 2022-01-15 07:23:49.177239: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:23:49.177316: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:23:49.177337: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:23:49.177353: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:23:49.177369: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# Iteration 0
# Iteration 1
# Reuse is on!
# Iteration 2
# Reuse is on!
# Restoring checkpoint /home/pc/Desktop/DeepMimicBvh/hmr/src/../models/model.ckpt-667589..
# /home/pc/Desktop/DeepMimicBvh/hmr/src/util/renderer.py:313: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(image.dtype, np.float):
#
# Result is in hmr/output (you can open images in Colaboratory by double-clicking them)
# Processing taekwondokick1017
# 2022-01-15 07:24:06.111650: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:24:06.111687: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:24:06.111697: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:24:06.111708: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:24:06.111746: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# Iteration 0
# Iteration 1
# Reuse is on!
# Iteration 2
# Reuse is on!
# Restoring checkpoint /home/pc/Desktop/DeepMimicBvh/hmr/src/../models/model.ckpt-667589..
# /home/pc/Desktop/DeepMimicBvh/hmr/src/util/renderer.py:313: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(image.dtype, np.float):
#
# Result is in hmr/output (you can open images in Colaboratory by double-clicking them)
# Processing taekwondokick1018
# 2022-01-15 07:24:24.620709: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:24:24.620759: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:24:24.620769: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:24:24.620777: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:24:24.620789: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# Iteration 0
# Iteration 1
# Reuse is on!
# Iteration 2
# Reuse is on!
# Restoring checkpoint /home/pc/Desktop/DeepMimicBvh/hmr/src/../models/model.ckpt-667589..
# /home/pc/Desktop/DeepMimicBvh/hmr/src/util/renderer.py:313: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(image.dtype, np.float):
#
# Result is in hmr/output (you can open images in Colaboratory by double-clicking them)
# Processing taekwondokick1019
# 2022-01-15 07:24:39.381358: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:24:39.381399: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:24:39.381409: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:24:39.381418: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:24:39.381456: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# Iteration 0
# Iteration 1
# Reuse is on!
# Iteration 2
# Reuse is on!
# Restoring checkpoint /home/pc/Desktop/DeepMimicBvh/hmr/src/../models/model.ckpt-667589..
# /home/pc/Desktop/DeepMimicBvh/hmr/src/util/renderer.py:313: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(image.dtype, np.float):
#
# Result is in hmr/output (you can open images in Colaboratory by double-clicking them)
# Processing taekwondokick1020
# 2022-01-15 07:24:55.083243: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:24:55.083281: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:24:55.083291: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:24:55.083335: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:24:55.083355: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# Iteration 0
# Iteration 1
# Reuse is on!
# Iteration 2
# Reuse is on!
# Restoring checkpoint /home/pc/Desktop/DeepMimicBvh/hmr/src/../models/model.ckpt-667589..
# /home/pc/Desktop/DeepMimicBvh/hmr/src/util/renderer.py:313: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(image.dtype, np.float):
#
# Result is in hmr/output (you can open images in Colaboratory by double-clicking them)
# Processing taekwondokick1021
# 2022-01-15 07:25:09.051552: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:25:09.051601: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:25:09.051627: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:25:09.051643: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:25:09.051659: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# Iteration 0
# Iteration 1
# Reuse is on!
# Iteration 2
# Reuse is on!
# Restoring checkpoint /home/pc/Desktop/DeepMimicBvh/hmr/src/../models/model.ckpt-667589..
# /home/pc/Desktop/DeepMimicBvh/hmr/src/util/renderer.py:313: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(image.dtype, np.float):
#
# Result is in hmr/output (you can open images in Colaboratory by double-clicking them)
# Processing taekwondokick1022
# 2022-01-15 07:25:22.637945: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:25:22.637998: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:25:22.638101: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:25:22.638128: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:25:22.638141: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# Iteration 0
# Iteration 1
# Reuse is on!
# Iteration 2
# Reuse is on!
# Restoring checkpoint /home/pc/Desktop/DeepMimicBvh/hmr/src/../models/model.ckpt-667589..
# /home/pc/Desktop/DeepMimicBvh/hmr/src/util/renderer.py:313: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(image.dtype, np.float):
#
# Result is in hmr/output (you can open images in Colaboratory by double-clicking them)
# Processing taekwondokick1023
# 2022-01-15 07:25:38.049231: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:25:38.049278: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:25:38.049295: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:25:38.049308: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:25:38.049321: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# Iteration 0
# Iteration 1
# Reuse is on!
# Iteration 2
# Reuse is on!
# Restoring checkpoint /home/pc/Desktop/DeepMimicBvh/hmr/src/../models/model.ckpt-667589..
# /home/pc/Desktop/DeepMimicBvh/hmr/src/util/renderer.py:313: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(image.dtype, np.float):
#
# Result is in hmr/output (you can open images in Colaboratory by double-clicking them)
# Processing taekwondokick1024
# 2022-01-15 07:25:53.260886: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:25:53.260926: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:25:53.260936: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:25:53.260944: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:25:53.260956: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# Iteration 0
# Iteration 1
# Reuse is on!
# Iteration 2
# Reuse is on!
# Restoring checkpoint /home/pc/Desktop/DeepMimicBvh/hmr/src/../models/model.ckpt-667589..
# /home/pc/Desktop/DeepMimicBvh/hmr/src/util/renderer.py:313: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(image.dtype, np.float):
#
# Result is in hmr/output (you can open images in Colaboratory by double-clicking them)
# Processing taekwondokick1025
# 2022-01-15 07:26:07.255734: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:26:07.255772: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:26:07.255782: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:26:07.255790: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:26:07.255798: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# Iteration 0
# Iteration 1
# Reuse is on!
# Iteration 2
# Reuse is on!
# Restoring checkpoint /home/pc/Desktop/DeepMimicBvh/hmr/src/../models/model.ckpt-667589..
# /home/pc/Desktop/DeepMimicBvh/hmr/src/util/renderer.py:313: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(image.dtype, np.float):
#
# Result is in hmr/output (you can open images in Colaboratory by double-clicking them)
# Processing taekwondokick1026
# 2022-01-15 07:26:20.114944: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:26:20.114992: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:26:20.115002: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:26:20.115011: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:26:20.115019: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# Iteration 0
# Iteration 1
# Reuse is on!
# Iteration 2
# Reuse is on!
# Restoring checkpoint /home/pc/Desktop/DeepMimicBvh/hmr/src/../models/model.ckpt-667589..
# /home/pc/Desktop/DeepMimicBvh/hmr/src/util/renderer.py:313: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(image.dtype, np.float):
#
# Result is in hmr/output (you can open images in Colaboratory by double-clicking them)
# Processing taekwondokick1027
# 2022-01-15 07:26:33.040295: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:26:33.040351: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:26:33.040370: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:26:33.040387: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:26:33.040407: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# Iteration 0
# Iteration 1
# Reuse is on!
# Iteration 2
# Reuse is on!
# Restoring checkpoint /home/pc/Desktop/DeepMimicBvh/hmr/src/../models/model.ckpt-667589..
# /home/pc/Desktop/DeepMimicBvh/hmr/src/util/renderer.py:313: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(image.dtype, np.float):
#
# Result is in hmr/output (you can open images in Colaboratory by double-clicking them)
# Processing taekwondokick1028
# 2022-01-15 07:26:46.013354: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:26:46.013394: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:26:46.013404: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:26:46.013413: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:26:46.013426: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# Iteration 0
# Iteration 1
# Reuse is on!
# Iteration 2
# Reuse is on!
# Restoring checkpoint /home/pc/Desktop/DeepMimicBvh/hmr/src/../models/model.ckpt-667589..
# /home/pc/Desktop/DeepMimicBvh/hmr/src/util/renderer.py:313: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(image.dtype, np.float):
#
# Result is in hmr/output (you can open images in Colaboratory by double-clicking them)
# Processing taekwondokick1029
# 2022-01-15 07:26:59.083851: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:26:59.083890: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:26:59.083900: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:26:59.083909: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:26:59.083922: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# Iteration 0
# Iteration 1
# Reuse is on!
# Iteration 2
# Reuse is on!
# Restoring checkpoint /home/pc/Desktop/DeepMimicBvh/hmr/src/../models/model.ckpt-667589..
# ...
# 2022-01-15 07:32:20.606318: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:32:20.606330: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# Iteration 0
# Iteration 1
# Reuse is on!
# Iteration 2
# Reuse is on!
# Restoring checkpoint /home/pc/Desktop/DeepMimicBvh/hmr/src/../models/model.ckpt-667589..
# /home/pc/Desktop/DeepMimicBvh/hmr/src/util/renderer.py:313: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(image.dtype, np.float):
#
# Result is in hmr/output (you can open images in Colaboratory by double-clicking them)
# Processing taekwondokick1054
# 2022-01-15 07:32:33.955768: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:32:33.955808: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:32:33.955817: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:32:33.955826: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:32:33.955837: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# Iteration 0
# Iteration 1
# Reuse is on!
# Iteration 2
# Reuse is on!
# Restoring checkpoint /home/pc/Desktop/DeepMimicBvh/hmr/src/../models/model.ckpt-667589..
# /home/pc/Desktop/DeepMimicBvh/hmr/src/util/renderer.py:313: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(image.dtype, np.float):
#
# Result is in hmr/output (you can open images in Colaboratory by double-clicking them)
# Processing taekwondokick1055
# 2022-01-15 07:32:47.150319: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:32:47.150359: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:32:47.150369: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:32:47.150378: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:32:47.150391: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# Iteration 0
# Iteration 1
# Reuse is on!
# Iteration 2
# Reuse is on!
# Restoring checkpoint /home/pc/Desktop/DeepMimicBvh/hmr/src/../models/model.ckpt-667589..
# /home/pc/Desktop/DeepMimicBvh/hmr/src/util/renderer.py:313: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(image.dtype, np.float):
#
# Result is in hmr/output (you can open images in Colaboratory by double-clicking them)
# Processing taekwondokick1056
# 2022-01-15 07:33:00.481873: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:33:00.481955: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:33:00.481984: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:33:00.482010: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:33:00.482034: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# Iteration 0
# Iteration 1
# Reuse is on!
# Iteration 2
# Reuse is on!
# Restoring checkpoint /home/pc/Desktop/DeepMimicBvh/hmr/src/../models/model.ckpt-667589..
# /home/pc/Desktop/DeepMimicBvh/hmr/src/util/renderer.py:313: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(image.dtype, np.float):
#
# Result is in hmr/output (you can open images in Colaboratory by double-clicking them)
# Processing taekwondokick1057
# 2022-01-15 07:33:13.622491: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:33:13.622532: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:33:13.622542: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:33:13.622550: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:33:13.622558: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# Iteration 0
# Iteration 1
# Reuse is on!
# Iteration 2
# Reuse is on!
# Restoring checkpoint /home/pc/Desktop/DeepMimicBvh/hmr/src/../models/model.ckpt-667589..
# /home/pc/Desktop/DeepMimicBvh/hmr/src/util/renderer.py:313: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(image.dtype, np.float):
#
# Result is in hmr/output (you can open images in Colaboratory by double-clicking them)
# Processing taekwondokick1058
# 2022-01-15 07:33:29.739482: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:33:29.739521: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:33:29.739531: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:33:29.739540: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:33:29.739666: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# Iteration 0
# Iteration 1
# Reuse is on!
# Iteration 2
# Reuse is on!
# Restoring checkpoint /home/pc/Desktop/DeepMimicBvh/hmr/src/../models/model.ckpt-667589..
# /home/pc/Desktop/DeepMimicBvh/hmr/src/util/renderer.py:313: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(image.dtype, np.float):
#
# Result is in hmr/output (you can open images in Colaboratory by double-clicking them)
# Processing taekwondokick1059
# 2022-01-15 07:33:46.029711: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:33:46.030305: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:33:46.030341: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:33:46.030361: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:33:46.030380: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# Iteration 0
# Iteration 1
# Reuse is on!
# Iteration 2
# Reuse is on!
# Restoring checkpoint /home/pc/Desktop/DeepMimicBvh/hmr/src/../models/model.ckpt-667589..
# /home/pc/Desktop/DeepMimicBvh/hmr/src/util/renderer.py:313: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(image.dtype, np.float):
#
# Result is in hmr/output (you can open images in Colaboratory by double-clicking them)
# Processing taekwondokick1060
# 2022-01-15 07:34:04.796340: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:34:04.796394: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:34:04.796410: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:34:04.796423: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:34:04.796436: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# Iteration 0
# Iteration 1
# Reuse is on!
# Iteration 2
# Reuse is on!
# Restoring checkpoint /home/pc/Desktop/DeepMimicBvh/hmr/src/../models/model.ckpt-667589..
# /home/pc/Desktop/DeepMimicBvh/hmr/src/util/renderer.py:313: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(image.dtype, np.float):
#
# Result is in hmr/output (you can open images in Colaboratory by double-clicking them)
# Processing taekwondokick1061
# 2022-01-15 07:34:22.685862: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:34:22.685913: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:34:22.685924: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:34:22.685933: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:34:22.685958: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# Iteration 0
# Iteration 1
# Reuse is on!
# Iteration 2
# Reuse is on!
# Restoring checkpoint /home/pc/Desktop/DeepMimicBvh/hmr/src/../models/model.ckpt-667589..
# /home/pc/Desktop/DeepMimicBvh/hmr/src/util/renderer.py:313: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(image.dtype, np.float):
#
# Result is in hmr/output (you can open images in Colaboratory by double-clicking them)
# Processing taekwondokick1062
# 2022-01-15 07:34:35.821920: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:34:35.821959: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:34:35.821969: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:34:35.821978: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2022-01-15 07:34:35.821989: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# Iteration 0
# Iteration 1
# Reuse is on!
# Iteration 2
# Reuse is on!
# Restoring checkpoint /home/pc/Desktop/DeepMimicBvh/hmr/src/../models/model.ckpt-667589..
# /home/pc/Desktop/DeepMimicBvh/hmr/src/util/renderer.py:313: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(image.dtype, np.float):
#
# Result is in hmr/output (you can open images in Colaboratory by double-clicking them)
# Done

# %% [markdown]
# Join csv files

# %%
import glob
import pandas as pd
path = 'hmr/output/csv/'                   
all_files = glob.glob(os.path.join(path, "*.csv"))
all_files.sort(key=lambda x: int(x.split('/')[-1].split('.')[0][-4:]))

df_from_each_file = (pd.read_csv(f) for f in all_files)
concatenated_df   = pd.concat(df_from_each_file, ignore_index=True)

concatenated_df['frame'] = concatenated_df.index+1
concatenated_df.to_csv("hmr/output/csv_joined/csv_joined.csv", index=False)

# %% [markdown]
# Convert generated csv to BVH file.

# %%
#convert estimated .csv files to bvh
# !./blender276/blender --background hmr/csv_to_bvh.blend -noaudio -P hmr/csv_to_bvh.py
# Out:
# found bundled python: /home/pc/Desktop/DeepMimicBvh/blender276/2.76/python
# read blend: /home/pc/Desktop/DeepMimicBvh/hmr/csv_to_bvh.blend
# [bpy.data.objects['Ankle.R'], bpy.data.objects['Knee.R'], bpy.data.objects['Hip.R'], bpy.data.objects['Hip.L'], bpy.data.objects['Knee.L'], bpy.data.objects['Ankle.L'], bpy.data.objects['Wrist.R'], bpy.data.objects['Elbow.R'], bpy.data.objects['Shoulder.R'], bpy.data.objects['Shoulder.L'], bpy.data.objects['Elbow.L'], bpy.data.objects['Wrist.L'], bpy.data.objects['Neck'], bpy.data.objects['Head'], bpy.data.objects['Nose'], bpy.data.objects['Eye.L'], bpy.data.objects['Eye.R'], bpy.data.objects['Ear.L'], bpy.data.objects['Ear.R'], bpy.data.objects['Hip.Center']]
# BVH Exported: hmr/output/bvh_animation/estimated_animation.bvh frames:64
#
# Error, region type 4 missing in - name:"Action", id:12
# Error, region type 4 missing in - name:"Action", id:12
#
# Blender quit
